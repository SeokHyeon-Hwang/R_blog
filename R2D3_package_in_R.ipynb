# %% [markdown]
# # R2D3 in R

# %% [markdown]
# ### install packages in Jupyter notebook, but it doesn't work.

# %%
install.packages('r2d3')
# Out:
# Installing package into 'C:/Users/Tokiri/Documents/R/win-library/3.5'
# (as 'lib' is unspecified)
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'를 열 수 없습니다"
# package 'r2d3' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Tokiri\AppData\Local\Temp\RtmpwNKfWV\downloaded_packages

# %% [markdown]
# ### install packages in R, it is worked. But library() doesn't work.

# %% [markdown]
# ![r2d3_in_r_01.png]("https://github.com/SeokHyeon-Hwang/R_blog/blob/master/r2d3_in_r_01.png")

# %% [markdown]
# ![image.png](attachment:image.png)
